# %%
import os
os.chdir('./SwagGAN-main/')

# %%
ls
# Out:
# README.md     imgs/    notebooks/           train.py          utils/
# data/         losses/  requirements.txt     train_clip.py     visualization/
# download.sh*  models/  swaggan_config.json  train_swaggan.py

# %%
# !./download.sh
# Out:
# Pre trained models directory exists. Attemping to download pre-trained models.
# --2023-05-08 19:06:55--  http://storage.googleapis.com/deep_fashion_multimodal/pre_trained_models/checkpoint_0040_DeepLabV3_Fashion_Men.pth
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.62.128, 172.253.115.128, 172.253.63.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.62.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 158898517 (152M) [application/octet-stream]
# Saving to: ‘checkpoint_0040_DeepLabV3_Fashion_Men.pth.1’
#
# checkpoint_0040_Dee 100%[===================>] 151.54M  41.5MB/s    in 3.7s
#
# 2023-05-08 19:06:59 (41.5 MB/s) - ‘checkpoint_0040_DeepLabV3_Fashion_Men.pth.1’ saved [158898517/158898517]
#
# --2023-05-08 19:06:59--  http://storage.googleapis.com/deep_fashion_multimodal/pre_trained_models/checkpoint256_0040_DeepLabV3_Fashion_Men.pth
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.62.128, 172.253.115.128, 172.253.63.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.62.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 158899609 (152M) [application/octet-stream]
# Saving to: ‘checkpoint256_0040_DeepLabV3_Fashion_Men.pth.1’
#
# checkpoint256_0040_ 100%[===================>] 151.54M  49.8MB/s    in 3.0s
#
# 2023-05-08 19:07:02 (49.8 MB/s) - ‘checkpoint256_0040_DeepLabV3_Fashion_Men.pth.1’ saved [158899609/158899609]
#
# --2023-05-08 19:07:02--  http://storage.googleapis.com/deep_fashion_multimodal/pre_trained_models/e4e.pt
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.62.128, 172.253.115.128, 172.253.63.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.62.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 931663611 (889M) [application/octet-stream]
# Saving to: ‘e4e.pt.1’
#
# e4e.pt.1            100%[===================>] 888.50M  44.7MB/s    in 18s
#
# 2023-05-08 19:07:21 (49.3 MB/s) - ‘e4e.pt.1’ saved [931663611/931663611]
#
# --2023-05-08 19:07:21--  http://storage.googleapis.com/deep_fashion_multimodal/pre_trained_models/generator.pt
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.62.128, 172.253.115.128, 172.253.63.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.62.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 189536761 (181M) [application/octet-stream]
# Saving to: ‘generator.pt.1’
#
# generator.pt.1      100%[===================>] 180.76M  54.0MB/s    in 3.4s
#
# 2023-05-08 19:07:24 (52.9 MB/s) - ‘generator.pt.1’ saved [189536761/189536761]

# %%
# !conda install pytorch=1.8.0 torchvision cudatoolkit=11.1

# %%
# !pip install git+https://github.com/facebookresearch/detectron2@main#subdirectory=projects/DensePose
# Out:
# Collecting git+https://github.com/facebookresearch/detectron2@main#subdirectory=projects/DensePose
#   Cloning https://github.com/facebookresearch/detectron2 (to revision main) to /var/tmp/pip-req-build-c772vw94
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2 /var/tmp/pip-req-build-c772vw94
#   Resolved https://github.com/facebookresearch/detectron2 to commit d4a5f28e01b2babbaba9f90198fb95f5c661cccd
#   Preparing metadata (setup.py) ... done
# Collecting detectron2@ git+https://github.com/facebookresearch/detectron2.git (from detectron2-densepose==0.6)
#   Cloning https://github.com/facebookresearch/detectron2.git to /var/tmp/pip-install-39bkwh5f/detectron2_3e7e5b734d304fd68258aad2a7ff189d
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /var/tmp/pip-install-39bkwh5f/detectron2_3e7e5b734d304fd68258aad2a7ff189d
#   Resolved https://github.com/facebookresearch/detectron2.git to commit d4a5f28e01b2babbaba9f90198fb95f5c661cccd
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: av>=8.0.3 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2-densepose==0.6) (10.0.0)
# Requirement already satisfied: opencv-python-headless>=4.5.3.56 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2-densepose==0.6) (4.7.0.72)
# Requirement already satisfied: scipy>=1.5.4 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2-densepose==0.6) (1.10.1)
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from opencv-python-headless>=4.5.3.56->detectron2-densepose==0.6) (1.24.3)
# Requirement already satisfied: Pillow>=7.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (9.5.0)
# Requirement already satisfied: matplotlib in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (2.0.6)
# Requirement already satisfied: termcolor>=1.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (2.3.0)
# Requirement already satisfied: yacs>=0.1.8 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (0.1.8)
# Requirement already satisfied: tabulate in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (4.65.0)
# Requirement already satisfied: tensorboard in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (2.13.0)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (0.1.9)
# Requirement already satisfied: omegaconf>=2.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (1.3.2)
# Requirement already satisfied: black in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (23.3.0)
# Requirement already satisfied: packaging in /opt/conda/envs/adl2/lib/python3.9/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (6.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/conda/envs/adl2/lib/python3.9/site-packages (from hydra-core>=1.1->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (4.9.3)
# Requirement already satisfied: portalocker in /opt/conda/envs/adl2/lib/python3.9/site-packages (from iopath<0.1.10,>=0.1.7->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (2.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (5.12.0)
# Requirement already satisfied: click>=8.0.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (8.1.3)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (0.11.1)
# Requirement already satisfied: platformdirs>=2 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (3.5.0)
# Requirement already satisfied: tomli>=1.1.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (2.0.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (4.5.0)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (4.23.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (2.29.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (2.3.3)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (0.40.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (3.15.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (6.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->detectron2-densepose==0.6) (3.2.2)

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: absl-py==1.4.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.3 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (4.9.3)
# Requirement already satisfied: asttokens==2.2.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (2.2.1)
# Requirement already satisfied: av==10.0.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (10.0.0)
# Requirement already satisfied: backcall==0.2.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.2.0)
# Collecting backports.functools-lru-cache==1.6.4 (from -r requirements.txt (line 6))
#   Using cached backports.functools_lru_cache-1.6.4-py2.py3-none-any.whl (5.9 kB)
# Requirement already satisfied: black==23.3.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (23.3.0)
# Requirement already satisfied: cachetools==5.3.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (5.3.0)
# Collecting certifi==2022.12.7 (from -r requirements.txt (line 9))
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# Requirement already satisfied: charset-normalizer==3.1.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (3.1.0)
# Requirement already satisfied: click==8.1.3 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (8.1.3)
# Requirement already satisfied: cloudpickle==2.2.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (2.2.1)
# Collecting cmake==3.26.3 (from -r requirements.txt (line 13))
#   Using cached cmake-3.26.3-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
# Requirement already satisfied: comm==0.1.3 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (0.1.3)
# Requirement already satisfied: contourpy==1.0.7 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (1.0.7)
# Requirement already satisfied: cycler==0.11.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (0.11.0)
# Collecting Cython==0.29.34 (from -r requirements.txt (line 17))
#   Using cached Cython-0.29.34-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (2.0 MB)
# Requirement already satisfied: debugpy==1.6.7 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (1.6.7)
# Requirement already satisfied: decorator==5.1.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (5.1.1)
# Requirement already satisfied: detectron2==0.6 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (0.6)
# Requirement already satisfied: detectron2-densepose==0.6 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (0.6)
# Requirement already satisfied: executing==1.2.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (1.2.0)
# Collecting filelock==3.12.0 (from -r requirements.txt (line 24))
#   Using cached filelock-3.12.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: fonttools==4.39.3 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (4.39.3)
# Collecting fsspec==2023.4.0 (from -r requirements.txt (line 26))
#   Using cached fsspec-2023.4.0-py3-none-any.whl (153 kB)
# Requirement already satisfied: fvcore==0.1.5.post20221221 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (0.1.5.post20221221)
# Requirement already satisfied: google-auth==2.17.3 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib==1.0.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (1.0.0)
# Collecting google-cloud==0.34.0 (from -r requirements.txt (line 30))
#   Using cached google_cloud-0.34.0-py2.py3-none-any.whl (1.8 kB)
# Requirement already satisfied: grpcio==1.54.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (1.54.0)
# Collecting h5py==3.8.0 (from -r requirements.txt (line 32))
#   Using cached h5py-3.8.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
# Collecting huggingface-hub==0.14.1 (from -r requirements.txt (line 33))
#   Using cached huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
# Requirement already satisfied: hydra-core==1.3.2 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (1.3.2)
# Requirement already satisfied: idna==3.4 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (3.4)
# Requirement already satisfied: importlib-metadata==6.6.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (6.6.0)
# Requirement already satisfied: importlib-resources==5.12.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (5.12.0)
# Requirement already satisfied: iopath==0.1.9 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (0.1.9)
# Collecting ipykernel==6.22.0 (from -r requirements.txt (line 39))
#   Using cached ipykernel-6.22.0-py3-none-any.whl (149 kB)
# Collecting ipython==8.4.0 (from -r requirements.txt (line 40))
#   Using cached ipython-8.4.0-py3-none-any.whl (750 kB)
# Requirement already satisfied: jedi==0.18.2 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (0.18.2)
# Requirement already satisfied: Jinja2==3.1.2 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (3.1.2)
# Requirement already satisfied: jupyter_client==8.2.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (8.2.0)
# Requirement already satisfied: jupyter_core==5.3.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 44)) (5.3.0)
# Requirement already satisfied: kiwisolver==1.4.4 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (1.4.4)
# Collecting lit==16.0.3 (from -r requirements.txt (line 46))
#   Using cached lit-16.0.3.tar.gz (138 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Markdown==3.4.3 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 47)) (3.4.3)
# Requirement already satisfied: MarkupSafe==2.1.2 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 48)) (2.1.2)
# Requirement already satisfied: matplotlib==3.7.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 49)) (3.7.1)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 50)) (0.1.6)
# Collecting memory-profiler==0.61.0 (from -r requirements.txt (line 51))
#   Using cached memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# Collecting mock==5.0.2 (from -r requirements.txt (line 55))
#   Using cached mock-5.0.2-py3-none-any.whl (30 kB)
# Collecting mpmath==1.3.0 (from -r requirements.txt (line 56))
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Requirement already satisfied: mypy-extensions==1.0.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 57)) (1.0.0)
# Requirement already satisfied: nest-asyncio==1.5.6 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 58)) (1.5.6)
# Collecting networkx==3.1 (from -r requirements.txt (line 59))
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Collecting ninja==1.11.1 (from -r requirements.txt (line 60))
#   Using cached ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
# Requirement already satisfied: numpy==1.24.3 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 61)) (1.24.3)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from -r requirements.txt (line 62))
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from -r requirements.txt (line 63))
#   Using cached nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from -r requirements.txt (line 64))
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from -r requirements.txt (line 65))
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from -r requirements.txt (line 66))
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from -r requirements.txt (line 67))
#   Using cached nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from -r requirements.txt (line 68))
#   Using cached nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from -r requirements.txt (line 69))
#   Using cached nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from -r requirements.txt (line 70))
#   Using cached nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
# Collecting nvidia-nccl-cu11==2.14.3 (from -r requirements.txt (line 71))
#   Using cached nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
# Collecting nvidia-nvtx-cu11==11.7.91 (from -r requirements.txt (line 72))
#   Using cached nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
# Requirement already satisfied: oauthlib==3.2.2 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 73)) (3.2.2)
# Collecting olefile==0.46 (from -r requirements.txt (line 74))
#   Using cached olefile-0.46.zip (112 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: omegaconf==2.3.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 75)) (2.3.0)
# Collecting opencv-python==4.7.0.72 (from -r requirements.txt (line 76))
#   Using cached opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
# Requirement already satisfied: opencv-python-headless==4.7.0.72 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 77)) (4.7.0.72)
# Requirement already satisfied: packaging==23.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 78)) (23.1)
# Collecting pandas==2.0.1 (from -r requirements.txt (line 79))
#   Using cached pandas-2.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
# Requirement already satisfied: parso==0.8.3 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 80)) (0.8.3)
# Requirement already satisfied: pathspec==0.11.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 81)) (0.11.1)
# Requirement already satisfied: pexpect==4.8.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 82)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 83)) (0.7.5)
# Collecting Pillow==7.1.2 (from -r requirements.txt (line 84))
#   Using cached Pillow-7.1.2.tar.gz (38.9 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pip==23.1.2 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 85)) (23.1.2)
# Requirement already satisfied: platformdirs==3.5.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 86)) (3.5.0)
# Requirement already satisfied: portalocker==2.7.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 87)) (2.7.0)
# Requirement already satisfied: prompt-toolkit==3.0.38 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 88)) (3.0.38)
# Collecting protobuf==4.22.4 (from -r requirements.txt (line 89))
#   Using cached protobuf-4.22.4-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
# Requirement already satisfied: psutil==5.9.5 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 90)) (5.9.5)
# Requirement already satisfied: ptyprocess==0.7.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 91)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 92)) (0.2.2)
# Requirement already satisfied: pyasn1==0.5.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 93)) (0.5.0)
# Requirement already satisfied: pyasn1-modules==0.3.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 94)) (0.3.0)
# Requirement already satisfied: pycocotools==2.0.6 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 95)) (2.0.6)
# Requirement already satisfied: Pygments==2.15.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 96)) (2.15.1)
# Requirement already satisfied: pyparsing==3.0.9 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 97)) (3.0.9)
# Requirement already satisfied: python-dateutil==2.8.2 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 98)) (2.8.2)
# Collecting pytz==2023.3 (from -r requirements.txt (line 99))
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Requirement already satisfied: PyYAML==6.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 100)) (6.0)
# Requirement already satisfied: pyzmq==25.0.2 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 101)) (25.0.2)
# Collecting regex==2023.3.23 (from -r requirements.txt (line 102))
#   Using cached regex-2023.3.23-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (768 kB)
# Requirement already satisfied: requests==2.29.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 103)) (2.29.0)
# Requirement already satisfied: requests-oauthlib==1.3.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 104)) (1.3.1)
# Requirement already satisfied: rsa==4.9 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 105)) (4.9)
# Requirement already satisfied: scipy==1.10.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 106)) (1.10.1)
# Collecting seaborn==0.12.2 (from -r requirements.txt (line 107))
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Collecting setuptools==59.5.0 (from -r requirements.txt (line 108))
#   Using cached setuptools-59.5.0-py3-none-any.whl (952 kB)
# Requirement already satisfied: six==1.16.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 109)) (1.16.0)
# Requirement already satisfied: stack-data==0.6.2 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 110)) (0.6.2)
# Collecting sympy==1.11.1 (from -r requirements.txt (line 111))
#   Using cached sympy-1.11.1-py3-none-any.whl (6.5 MB)
# Requirement already satisfied: tabulate==0.9.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 112)) (0.9.0)
# Requirement already satisfied: tensorboard==2.13.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 113)) (2.13.0)
# Requirement already satisfied: tensorboard-data-server==0.7.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 114)) (0.7.0)
# Requirement already satisfied: termcolor==2.3.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 115)) (2.3.0)
# Collecting tokenizers==0.13.3 (from -r requirements.txt (line 116))
#   Using cached tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
# Requirement already satisfied: tomli==2.0.1 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 117)) (2.0.1)
# Collecting torch==1.8.0 (from -r requirements.txt (line 118))
#   Using cached torch-1.8.0-cp39-cp39-manylinux1_x86_64.whl (735.5 MB)
# Collecting torchvision==0.9.0 (from -r requirements.txt (line 120))
#   Downloading torchvision-0.9.0-cp39-cp39-manylinux1_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 81.4 MB/s eta 0:00:0000:0100:01
# Collecting tornado==6.3 (from -r requirements.txt (line 121))
#   Downloading tornado-6.3-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.4/426.4 kB 41.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm==4.65.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 122)) (4.65.0)
# Requirement already satisfied: traitlets==5.9.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 123)) (5.9.0)
# Collecting transformers==4.28.1 (from -r requirements.txt (line 124))
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 122.0 MB/s eta 0:00:0000:01
# Collecting triton==2.0.0 (from -r requirements.txt (line 125))
#   Downloading triton-2.0.0-1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 5.8 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: typing_extensions==4.5.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 126)) (4.5.0)
# Collecting tzdata==2023.3 (from -r requirements.txt (line 127))
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 595.5 kB/s eta 0:00:0000:01
# Requirement already satisfied: urllib3==1.26.15 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 128)) (1.26.15)
# Requirement already satisfied: wcwidth==0.2.6 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 129)) (0.2.6)
# Requirement already satisfied: Werkzeug==2.3.3 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 130)) (2.3.3)
# Requirement already satisfied: wheel==0.40.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 131)) (0.40.0)
# Requirement already satisfied: yacs==0.1.8 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 132)) (0.1.8)
# Requirement already satisfied: zipp==3.15.0 in /opt/conda/envs/adl2/lib/python3.9/site-packages (from -r requirements.txt (line 133)) (3.15.0)
# Collecting detectron2@ git+https://github.com/facebookresearch/detectron2.git (from detectron2-densepose==0.6->-r requirements.txt (line 22))
#   Cloning https://github.com/facebookresearch/detectron2.git to /var/tmp/pip-install-iits3mdt/detectron2_6c187459d45749f2be152450735d61e7
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /var/tmp/pip-install-iits3mdt/detectron2_6c187459d45749f2be152450735d61e7
#   Resolved https://github.com/facebookresearch/detectron2.git to commit d4a5f28e01b2babbaba9f90198fb95f5c661cccd
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: lit, olefile, Pillow
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-16.0.3-py3-none-any.whl size=88173 sha256=8b52a2bb1c3e6abd4d4c163fea80913a63e88b8699de67644ac08586b9e016ed
#   Stored in directory: /home/jf3482/.cache/pip/wheels/e0/ed/f5/a14343c01f340fb3081562725a52c71540eb6fda3d31dd004e
#   Building wheel for olefile (setup.py) ... done
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35417 sha256=702ca5042a95f84ca8cb522f94dd672897262e77f9c2004390edef94750bf11c
#   Stored in directory: /home/jf3482/.cache/pip/wheels/64/b8/ba/ebba30390fbd997074f35e42a842ce3fd933213cac8753414e
#   Building wheel for Pillow (setup.py) ... done
#   Created wheel for Pillow: filename=Pillow-7.1.2-cp39-cp39-linux_x86_64.whl size=529984 sha256=419171d74b9b1920d0c3d6376e928201f9ee4c4c93029e635ba508db0bb9fca9
#   Stored in directory: /home/jf3482/.cache/pip/wheels/d9/ba/21/c85acde07dec9bda5e06f54595c9bad9ea1c2733b003d2c38d
# Successfully built lit olefile Pillow
# Installing collected packages: tokenizers, pytz, ninja, mpmath, lit, google-cloud, cmake, tzdata, tornado, torch, sympy, setuptools, regex, protobuf, Pillow, opencv-python, olefile, nvidia-nccl-cu11, nvidia-cufft-cu11, nvidia-cuda-nvrtc-cu11, networkx, mock, memory-profiler, h5py, fsspec, filelock, Cython, certifi, backports.functools-lru-cache, triton, torchvision, pandas, nvidia-nvtx-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, seaborn, nvidia-cusolver-cu11, nvidia-cudnn-cu11, ipython, huggingface-hub, transformers, ipykernel
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.3.1
#     Uninstalling tornado-6.3.1:
#       Successfully uninstalled tornado-6.3.1
#   Attempting uninstall: torch
#     Found existing installation: torch 1.8.0.post3
#     Uninstalling torch-1.8.0.post3:
#       Successfully uninstalled torch-1.8.0.post3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.23.0
#     Uninstalling protobuf-4.23.0:
#       Successfully uninstalled protobuf-4.23.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.5.0
#     Uninstalling Pillow-9.5.0:
#       Successfully uninstalled Pillow-9.5.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.5.7
#     Uninstalling certifi-2023.5.7:
#       Successfully uninstalled certifi-2023.5.7
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.1a0+60a3e72
#     Uninstalling torchvision-0.15.1a0+60a3e72:
#       Successfully uninstalled torchvision-0.15.1a0+60a3e72
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.13.2
#     Uninstalling ipython-8.13.2:
#       Successfully uninstalled ipython-8.13.2
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.23.0
#     Uninstalling ipykernel-6.23.0:
#       Successfully uninstalled ipykernel-6.23.0
# Successfully installed Cython-0.29.34 Pillow-7.1.2 backports.functools-lru-cache-1.6.4 certifi-2022.12.7 cmake-3.26.3 filelock-3.12.0 fsspec-2023.4.0 google-cloud-0.34.0 h5py-3.8.0 huggingface-hub-0.14.1 ipykernel-6.22.0 ipython-8.4.0 lit-16.0.3 memory-profiler-0.61.0 mock-5.0.2 mpmath-1.3.0 networkx-3.1 ninja-1.11.1 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 olefile-0.46 opencv-python-4.7.0.72 pandas-2.0.1 protobuf-4.22.4 pytz-2023.3 regex-2023.3.23 seaborn-0.12.2 setuptools-59.5.0 sympy-1.11.1 tokenizers-0.13.3 torch-1.8.0 torchvision-0.9.0 tornado-6.3 transformers-4.28.1 triton-2.0.0 tzdata-2023.3
